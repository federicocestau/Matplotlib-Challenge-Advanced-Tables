# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
rain_df = pd.read_csv("C:/Users/User/Rain.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x260f272ec08>,
#   <matplotlib.axis.XTick at 0x260f272e288>,
#   <matplotlib.axis.XTick at 0x260f2724d08>,
#   <matplotlib.axis.XTick at 0x260f27f8e08>,
#   <matplotlib.axis.XTick at 0x260f2802588>,
#   <matplotlib.axis.XTick at 0x260f2802e08>,
#   <matplotlib.axis.XTick at 0x260f28087c8>,
#   <matplotlib.axis.XTick at 0x260f280c248>,
#   <matplotlib.axis.XTick at 0x260f280cb88>,
#   <matplotlib.axis.XTick at 0x260f2802bc8>,
#   <matplotlib.axis.XTick at 0x260f28113c8>,
#   <matplotlib.axis.XTick at 0x260f2811b08>,
#   <matplotlib.axis.XTick at 0x260f2815488>,
#   <matplotlib.axis.XTick at 0x260f2818148>,
#   <matplotlib.axis.XTick at 0x260f2818b48>,
#   <matplotlib.axis.XTick at 0x260f281c6c8>,
#   <matplotlib.axis.XTick at 0x260f281f248>,
#   <matplotlib.axis.XTick at 0x260f281fd88>,
#   <matplotlib.axis.XTick at 0x260f281fdc8>,
#   <matplotlib.axis.XTick at 0x260f2823148>,
#   <matplotlib.axis.XTick at 0x260f2823c08>,
#   <matplotlib.axis.XTick at 0x260f2826988>,
#   <matplotlib.axis.XTick at 0x260f2829288>,
#   <matplotlib.axis.XTick at 0x260f2829d88>,
#   <matplotlib.axis.XTick at 0x260f282d908>,
#   <matplotlib.axis.XTick at 0x260f2831488>,
#   <matplotlib.axis.XTick at 0x260f2835148>,
#   <matplotlib.axis.XTick at 0x260f2829248>,
#   <matplotlib.axis.XTick at 0x260f281c708>,
#   <matplotlib.axis.XTick at 0x260f2839388>,
#   <matplotlib.axis.XTick at 0x260f2839d48>,
#   <matplotlib.axis.XTick at 0x260f283c748>,
#   <matplotlib.axis.XTick at 0x260f283f208>,
#   <matplotlib.axis.XTick at 0x260f283fc08>,
#   <matplotlib.axis.XTick at 0x260f2843788>,
#   <matplotlib.axis.XTick at 0x260f2846308>,
#   <matplotlib.axis.XTick at 0x260f284a048>,
#   <matplotlib.axis.XTick at 0x260f2846e88>,
#   <matplotlib.axis.XTick at 0x260f284a208>,
#   <matplotlib.axis.XTick at 0x260f284d188>,
#   <matplotlib.axis.XTick at 0x260f284da88>,
#   <matplotlib.axis.XTick at 0x260f2850388>,
#   <matplotlib.axis.XTick at 0x260f2854048>,
#   <matplotlib.axis.XTick at 0x260f28549c8>,
#   <matplotlib.axis.XTick at 0x260f2857548>,
#   <matplotlib.axis.XTick at 0x260f285b208>,
#   <matplotlib.axis.XTick at 0x260f285bd48>,
#   <matplotlib.axis.XTick at 0x260f28500c8>,
#   <matplotlib.axis.XTick at 0x260f285f448>,
#   <matplotlib.axis.XTick at 0x260f285fe08>],
#  <a list of 50 Text xticklabel objects>)
